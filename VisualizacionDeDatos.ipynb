# %% [markdown]
# <a href="https://colab.research.google.com/github/Furtivo4/AnalisisdeDatos/blob/main/VisualizacionDeDatos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
#Ver linea simple
x = [1,2,3,4]
y = [1,2,3,4]

plt.plot(x,y)
plt.scatter(x,y)
plt.show()

# %%
#Grafico de barras
categorias = ['A', 'B', 'C', 'D']
valores = [10, 20, 30, 40]

plt.bar(categorias, valores)
plt.show()
